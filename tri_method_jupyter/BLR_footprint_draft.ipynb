# %%
import calc_footprint_FFP_climatology as myfootprint_s
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import xarray as xr
import shapefile
import rasterio
import cv2
from affine import Affine
from osgeo import gdal
import pygeodesy
import pyproj as proj
import cartopy.crs as ccrs
import traceback

# %%
test_img = 'p37r32_20170629_vernaleddysite_reflsurf_l8.tif'
test_raster = rasterio.open(test_img)
dst_crs = test_raster.crs
test_raster.close()

# %%
def bearing(endx,endy):
    '''
    Calculate bearing between the origin (0,0) and point (endx,endy)
    '''
    rad = -np.arctan2(endy-0,endx-0) + np.pi*0.5
    return (np.degrees(rad) + 360) % 360

# %%
def date_parse(yr,doy,hr):
    if '2400' in hr:
        hr = '000'
        return pd.datetime.strptime(f'{yr}{int(doy)+1}{int(hr):04}', '%Y%j%H%M')
    else:
        return pd.datetime.strptime(f'{yr}{doy}{int(hr):04}', '%Y%j%H%M')
    
def date_parse_sigv(doy,hr):
    yr='2018'
    return pd.datetime.strptime(f'{yr}{doy}{int(hr):04}', '%Y%j%H%M')

flux_df = pd.read_csv('V192.txt',delim_whitespace=True,parse_dates={'TIMESTAMP':[0,1,2]},date_parser=date_parse,index_col=0)
sigv_df = pd.read_csv('LW192.txt',delim_whitespace=True,parse_dates={'TIMESTAMP':[0,1]},date_parser=date_parse_sigv,index_col=0,names=['DOY','hrmin','mag_v','sig_v'])

test_df = pd.concat([flux_df,sigv_df],axis=1)
print(test_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3020                 result = tools.to_datetime(
# -> 3021                     date_parser(*date_cols), errors='ignore')
#    3022                 if isinstance(result, datetime.datetime):
#
# <ipython-input-28-10aa8fd33509> in date_parse(yr, doy, hr)
#       3         hr = '000'
# ----> 4         return pd.datetime.strptime(f'{yr}{int(doy)+1}{int(hr):04}', '%Y%j%H%M')
#       5     else:
#
# TypeError: only length-1 arrays can be converted to Python scalars
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3029                                                 parser=date_parser,
# -> 3030                                                 dayfirst=dayfirst),
#    3031                         errors='ignore')
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# TypeError: date_parse() missing 2 required positional arguments: 'doy' and 'hr'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-10aa8fd33509> in <module>()
#      10     return pd.datetime.strptime(f'{yr}{doy}{int(hr):04}', '%Y%j%H%M')
#      11
# ---> 12 flux_df = pd.read_csv('V192.txt',delim_whitespace=True,parse_dates={'TIMESTAMP':[0,1,2]},date_parser=date_parse,index_col=0)
#      13 sigv_df = pd.read_csv('LW192.txt',delim_whitespace=True,parse_dates={'TIMESTAMP':[0,1]},date_parser=date_parse_sigv,index_col=0,names=['DOY','hrmin','mag_v','sig_v'])
#      14
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1919             data = {k: v for k, (i, v) in zip(names, data)}
#    1920
# -> 1921             names, data = self._do_date_conversions(names, data)
#    1922             index, names = self._make_index(data, alldata, names)
#    1923
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _do_date_conversions(self, names, data)
#    1673             data, names = _process_date_conversion(
#    1674                 data, self._date_conv, self.parse_dates, self.index_col,
# -> 1675                 self.index_names, names, keep_date_col=self.keep_date_col)
#    1676
#    1677         return names, data
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    3083
#    3084             _, col, old_names = _try_convert_dates(converter, colspec,
# -> 3085                                                    data_dict, orig_names)
#    3086
#    3087             new_data[new_name] = col
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _try_convert_dates(parser, colspec, data_dict, columns)
#    3115     to_parse = [data_dict[c] for c in colnames if c in data_dict]
#    3116
# -> 3117     new_col = parser(*to_parse)
#    3118     return new_name, new_col, colnames
#    3119
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3031                         errors='ignore')
#    3032                 except Exception:
# -> 3033                     return generic_parser(date_parser, *date_cols)
#    3034
#    3035     return converter
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/date_converters.py in generic_parser(parse_func, *cols)
#      37     for i in range(N):
#      38         args = [c[i] for c in cols]
# ---> 39         results[i] = parse_func(*args)
#      40
#      41     return results
#
# <ipython-input-28-10aa8fd33509> in date_parse(yr, doy, hr)
#       4         return pd.datetime.strptime(f'{yr}{int(doy)+1}{int(hr):04}', '%Y%j%H%M')
#       5     else:
# ----> 6         return pd.datetime.strptime(f'{yr}{doy}{int(hr):04}', '%Y%j%H%M')
#       7
#       8 def date_parse_sigv(doy,hr):
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
# --> 365                           data_string[found.end():])
#     366
#     367     iso_year = year = None
#
# ValueError: unconverted data remains: 5

# %%
zm_s = 2.78
z0_s = 0.05
h_s = 2000.
test_df['ol'] = zm_s/test_df['z/L']
dx = 3.
orig_d = 600.
start_hr = 12
end_hr = 12

for indx, hr in enumerate(np.arange(start_hr,end_hr+1)):

    print(f'Hour: {hr}')
    
    temp_line = test_df.loc[test_df.index.hour == hr]

    try:
        temp_ffp = myfootprint_s.FFP_climatology(domain=[-orig_d,orig_d,-orig_d,orig_d],dx=dx,dy=dx,
                                zm=zm_s,z0=z0_s,h=h_s,rs=.9,
                                ol=temp_line.iloc[0].at['ol'],sigmav=temp_line.iloc[0].at['sig_v'],
                                ustar=temp_line.iloc[0].at['ustar'],wind_dir=temp_line.iloc[0].at['Dir'],
                                crop=0,fig=0,verbosity=2)
    except Exception as e:
        if indx == 0:
            new_dat = rasterio.open('test_footprint.tif','w',driver='GTiff',dtype=rasterio.float64,
                                   count=len(np.arange(start_hr,end_hr+1)),height=f_2d.shape[0],width=f_2d.shape[1],
                                    affine=aff_trans,crs='+proj=latlong',nodata=0.00000000e+000)
    
        print(f'Hour {hr} footprint failed, band {indx+1} not written.')
        print(e)
        continue
    
    f_2d = np.array(temp_ffp['fclim_2d'])
    x_2d = np.array(temp_ffp['x_2d'])
    y_2d = np.array(temp_ffp['y_2d'])
    f_2d = f_2d*dx**2
    
    t_f2d = f_2d.flatten()
    df_f2d = pd.DataFrame({'f2d':t_f2d}).sort_values(by='f2d').iloc[::-1]
    fullsum = df_f2d['f2d'].sum()
    df_f2d['cumsum_f2d'] = df_f2d['f2d'].cumsum()
    gb_df_f2d = df_f2d.groupby('f2d',as_index=True).mean()
    diff = abs(gb_df_f2d['cumsum_f2d']-0.9)
    cutoff = diff.idxmin()
    
    f_2d = np.where(f_2d>=cutoff,f_2d,np.nan)
    f_2d = np.nan_to_num(f_2d)
    
    bear = bearing(x_2d,y_2d)
    plt.pcolormesh(bear)
    plt.colorbar()
    plt.show()

    dist = np.hypot(x_2d,y_2d)
    lon = np.zeros(f_2d.shape)
    lat = np.zeros(f_2d.shape)
    
    station = pygeodesy.ellipsoidalVincenty.LatLon(40.45829,-109.5626)
    
    for i in np.arange(0,f_2d.shape[0]):
        for j in np.arange(0,f_2d.shape[1]):
            (lat[i,j],lon[i,j]) = station.destination(dist[i,j],bear[i,j]).latlon
    
    plt.pcolormesh(lon,lat,f_2d)
    plt.show()
    
    '''fig = plt.figure(figsize=(14,7))
    ax1 = fig.add_subplot(211)
    ax2 = fig.add_subplot(212)
    im1 = ax1.imshow(lat,origin='lower')
    fig.colorbar(im1,ax=ax1)
    im2 = ax2.imshow(lon,origin='lower')
    fig.colorbar(im2,ax=ax2)
    plt.show()'''

    shape = f_2d.shape
    
    ys = [0,0,shape[0]-1]
    xs = [0,shape[0]-1,shape[1]-1]

    new = np.float32([[lon[i,j],lat[i,j]] for i,j in zip(ys,xs)])
    old = np.float32([[i,j] for i,j in zip(ys,xs)])
    #new = np.float32([[lon[shape[0]-1-i,j],lat[shape[0]-1-i,j]] for i,j in zip(ys,xs)])
    #old = np.float32([[i,j] for i,j in zip(ys,xs)])
    
    print(new)
    print(old)
    
    aff_trans = Affine(*cv2.getAffineTransform(old,new).flatten())
    print((0,0) * aff_trans)
    #f_2d.dtype
    print(cv2.getAffineTransform(old,new).flatten())
    
    if indx == 0:
        new_dat = rasterio.open('test_footprint.tif','w',driver='GTiff',dtype=rasterio.float64,
                               count=len(np.arange(start_hr,end_hr+1)),height=f_2d.shape[0],width=f_2d.shape[1],
                                affine=aff_trans,crs='+proj=latlong',nodata=0.00000000e+000)
    
    new_dat.write(f_2d,indx+1)
    tag_dict = {'hour':f'{hr*100:04}','wind_dir':temp_line.iloc[0].at['Dir'],'total_footprint':gb_df_f2d['cumsum_f2d'].loc[cutoff]}
    new_dat.update_tags(indx+1,**tag_dict)


new_dat.close()
# Out:
# Hour: 7
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# Hour 7 footprint failed, band 1 not written.
# local variable 'psi_f' referenced before assignment
# Hour: 8
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# Hour 8 footprint failed, band 2 not written.
# local variable 'psi_f' referenced before assignment
# Hour: 9
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# Hour 9 footprint failed, band 3 not written.
# local variable 'psi_f' referenced before assignment
# Hour: 10
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# Hour 10 footprint failed, band 4 not written.
# local variable 'psi_f' referenced before assignment
# Hour: 11
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# Hour 11 footprint failed, band 5 not written.
# local variable 'psi_f' referenced before assignment
# Hour: 12
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 13
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 14
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 15
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 16
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 17
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 18
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 19
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# [[-109.56967163   40.45288467]
#  [-109.55552673   40.45288467]
#  [-109.55552673   40.46369171]]
# [[   0.    0.]
#  [   0.  400.]
#  [ 400.  400.]]
# (-109.56967163085938, 40.452884674072266)
# [  0.00000000e+00   3.53622437e-05  -1.09569672e+02   2.70175934e-05
#    0.00000000e+00   4.04528847e+01]
# Hour: 20
#
# Alert(0017):
#  Only one value of zm passed. Using it for all footprints.
#  Execution continues.
#
# Alert(0013):
#  Using z0, ignoring umean if passed.
#  Execution continues.
#
# Calculating footprint  1  of  1
# Hour 20 footprint failed, band 14 not written.
# local variable 'psi_f' referenced before assignment

# %%
out_file = 'albers_doy_footprint.tif'

from rasterio.warp import calculate_default_transform, reproject, Resampling

with rasterio.open('test_footprint.tif','r+') as src:
    transform,width,height = calculate_default_transform(src.crs,dst_crs,src.width,src.height,*src.bounds,resolution=3.)
    
    kwargs = src.meta.copy()
    kwargs.update({
        'crs': dst_crs,
        'transform': transform,
        'width': width,
        'height': height
    })
    
    
    with rasterio.open(out_file,'w',**kwargs) as dst:
        for i in range(1, src.count+1):
            reproject(
                source=rasterio.band(src, i),
                destination=rasterio.band(dst, i),
                src_transform=src.affine,
                src_crs=src.crs,
                dst_transform=transform,
                dst_crs=dst_crs)#,
                #resampling=Resampling.nearest)
            try:
                dst.update_tags(i,**src.tags(i))
            except:
                continue
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefined                           Traceback (most recent call last)
# <ipython-input-6-f7adc6e07b0f> in <module>()
#       4
#       5 with rasterio.open('test_footprint.tif','r+') as src:
# ----> 6     transform,width,height = calculate_default_transform(src.crs,dst_crs,src.width,src.height,*src.bounds,resolution=3.)
#       7
#       8     kwargs = src.meta.copy()
#
# ~/anaconda3/lib/python3.6/site-packages/rasterio/warp.py in calculate_default_transform(src_crs, dst_crs, width, height, left, bottom, right, top, resolution)
#     332         src_crs, dst_crs,
#     333         width, height,
# --> 334         left, bottom, right, top)
#     335
#     336     # If resolution is specified, Keep upper-left anchored
#
# rasterio/_warp.pyx in rasterio._warp._calculate_default_transform (rasterio/_warp.cpp:11848)()
#
# rasterio/_warp.pyx in rasterio._warp._calculate_default_transform (rasterio/_warp.cpp:11612)()
#
# rasterio/_warp.pyx in rasterio._warp._calculate_default_transform (rasterio/_warp.cpp:11394)()
#
# rasterio/_warp.pyx in rasterio._warp._calculate_default_transform (rasterio/_warp.cpp:11308)()
#
# rasterio/_err.pyx in rasterio._err.CPLErrors.check (rasterio/_err.c:1773)()
#
# CPLE_AppDefined: Cannot invert geotransform

# %%
from rasterio.plot import show
ds = rasterio.open('test_footprint.tif')
count = ds.count
for i in np.arange(1,ds.count+1):
    print(ds.tags(i))
    show((ds,int(i)),cmap='pink')
plt.show()
# Out:
# {'hour': '0700', 'total_footprint': '0.900006383949', 'wind_dir': '330.1'}
# /Users/miksch/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2961: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=-109.56967163085938, right=-109.56967163085938
#   'left=%s, right=%s') % (left, right))
# /Users/miksch/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3285: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=40.452884674072266, top=40.452884674072266
#   'bottom=%s, top=%s') % (bottom, top))
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
